# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %matplotlib notebook

# %%
import gmag.arrays.image as image
import pandas as pd
import matplotlib.pyplot as plt

# %%
fl = image.list_files('2012-01-01',ndays=2)
fl.head()
# Out:
#         date                    fname                                 dir
# 0 2012-01-01  image2012010100.col2.gz  D:\data\magnetometer\IMAGE\2012\01
# 1 2012-01-02  image2012010200.col2.gz  D:\data\magnetometer\IMAGE\2012\01

# %%
#test download
image.download('2019-01-01',ndays=10, force=True)
# Out:
# https://space.fmi.fi/image/www/data_download.php?starttime=20190101&length=1440&format=text&sample_rate=10&compress
# -1 / unknown
#  D:\data\magnetometer\IMAGE\2019\01\image2019010100.col2.gz
# https://space.fmi.fi/image/www/data_download.php?starttime=20190102&length=1440&format=text&sample_rate=10&compress
# -1 / unknown
#  D:\data\magnetometer\IMAGE\2019\01\image2019010200.col2.gz
# https://space.fmi.fi/image/www/data_download.php?starttime=20190103&length=1440&format=text&sample_rate=10&compress
# -1 / unknown
#  D:\data\magnetometer\IMAGE\2019\01\image2019010300.col2.gz
# https://space.fmi.fi/image/www/data_download.php?starttime=20190104&length=1440&format=text&sample_rate=10&compress
# -1 / unknown
#  D:\data\magnetometer\IMAGE\2019\01\image2019010400.col2.gz
# https://space.fmi.fi/image/www/data_download.php?starttime=20190105&length=1440&format=text&sample_rate=10&compress
# -1 / unknown
#  D:\data\magnetometer\IMAGE\2019\01\image2019010500.col2.gz
# https://space.fmi.fi/image/www/data_download.php?starttime=20190106&length=1440&format=text&sample_rate=10&compress
# -1 / unknown
#  D:\data\magnetometer\IMAGE\2019\01\image2019010600.col2.gz
# https://space.fmi.fi/image/www/data_download.php?starttime=20190107&length=1440&format=text&sample_rate=10&compress
# -1 / unknown
#  D:\data\magnetometer\IMAGE\2019\01\image2019010700.col2.gz
# https://space.fmi.fi/image/www/data_download.php?starttime=20190108&length=1440&format=text&sample_rate=10&compress
# -1 / unknown
#  D:\data\magnetometer\IMAGE\2019\01\image2019010800.col2.gz
# https://space.fmi.fi/image/www/data_download.php?starttime=20190109&length=1440&format=text&sample_rate=10&compress
# -1 / unknown
#  D:\data\magnetometer\IMAGE\2019\01\image2019010900.col2.gz
# https://space.fmi.fi/image/www/data_download.php?starttime=20190110&length=1440&format=text&sample_rate=10&compress
# -1 / unknown
#  D:\data\magnetometer\IMAGE\2019\01\image2019011000.col2.gz

# %%
df=image.load(site='AND',sdate='2019-01-01',ndays=10)
# Out:
# D:\data\magnetometer\IMAGE\2019\01\image2019010100.col2.gz
# D:\data\magnetometer\IMAGE\2019\01\image2019010200.col2.gz
# D:\data\magnetometer\IMAGE\2019\01\image2019010300.col2.gz
# D:\data\magnetometer\IMAGE\2019\01\image2019010400.col2.gz
# D:\data\magnetometer\IMAGE\2019\01\image2019010500.col2.gz
# D:\data\magnetometer\IMAGE\2019\01\image2019010600.col2.gz
# D:\data\magnetometer\IMAGE\2019\01\image2019010700.col2.gz
# D:\data\magnetometer\IMAGE\2019\01\image2019010800.col2.gz
# D:\data\magnetometer\IMAGE\2019\01\image2019010900.col2.gz
# D:\data\magnetometer\IMAGE\2019\01\image2019011000.col2.gz

# %%
df.head()
df.tail()
# Out:
#                        AND_X   AND_Y    AND_Z         AND_H      AND_D  \
# t
# 2019-01-01 00:00:00  10867.6  1398.7  52336.6  10956.799773  98.133477
# 2019-01-01 00:00:10  10868.1  1397.5  52337.3  10957.153719  96.882589
# 2019-01-01 00:00:20  10869.4  1396.6  52336.1  10958.337632  95.834566
# 2019-01-01 00:00:30  10869.2  1395.3  52335.9  10957.984656  94.567520
# 2019-01-01 00:00:40  10867.5  1394.5  52335.9  10956.201677  93.975078
#
#                      AND_declination  AND_cgmlat  AND_cgmlon  AND_lshell  \
# t
# 2019-01-01 00:00:00          6.82071    66.72492    98.78456    6.404496
# 2019-01-01 00:00:10          6.82071    66.72492    98.78456    6.404496
# 2019-01-01 00:00:20          6.82071    66.72492    98.78456    6.404496
# 2019-01-01 00:00:30          6.82071    66.72492    98.78456    6.404496
# 2019-01-01 00:00:40          6.82071    66.72492    98.78456    6.404496
#
#                      AND_mlt
# t
# 2019-01-01 00:00:00  22.6678
# 2019-01-01 00:00:10  22.6678
# 2019-01-01 00:00:20  22.6678
# 2019-01-01 00:00:30  22.6678
# 2019-01-01 00:00:40  22.6678
#                        AND_X   AND_Y    AND_Z         AND_H       AND_D  \
# t
# 2019-01-10 23:59:10  10858.9  1403.0  52346.4  10948.672027  103.436282
# 2019-01-10 23:59:20  10858.9  1403.3  52346.4  10948.707655  103.734158
# 2019-01-10 23:59:30  10858.6  1403.5  52346.1  10948.433531  103.968372
# 2019-01-10 23:59:40  10858.4  1403.5  52346.1  10948.234947  103.992124
# 2019-01-10 23:59:50  10858.4  1403.5  52346.1  10948.234947  103.992124
#
#                      AND_declination  AND_cgmlat  AND_cgmlon  AND_lshell  \
# t
# 2019-01-10 23:59:10          6.82071    66.72492    98.78456    6.404496
# 2019-01-10 23:59:20          6.82071    66.72492    98.78456    6.404496
# 2019-01-10 23:59:30          6.82071    66.72492    98.78456    6.404496
# 2019-01-10 23:59:40          6.82071    66.72492    98.78456    6.404496
# 2019-01-10 23:59:50          6.82071    66.72492    98.78456    6.404496
#
#                      AND_mlt
# t
# 2019-01-10 23:59:10  22.6678
# 2019-01-10 23:59:20  22.6678
# 2019-01-10 23:59:30  22.6678
# 2019-01-10 23:59:40  22.6678
# 2019-01-10 23:59:50  22.6678

# %%
# not you can plot with panda's, however there
#is an issue with determining the x-axis ticks
#which serverly slows plotting and is extremely
#memory intesive
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
plt.plot(df['AND_X'])
# Out:
# <img src="data:image/png;base64,..." width="842">

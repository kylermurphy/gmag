# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %matplotlib notebook

# %%
import gmag.arrays.themis as themis
import pandas as pd
import matplotlib.pyplot as plt

# %%
fl = themis.list_files('KUUJ','2012-01-01',ndays=2)
fl.head()
# Out:
#         date                             fname  \
# 0 2012-01-01  thg_l2_mag_kuuj_20120101_v01.cdf
# 1 2012-01-02  thg_l2_mag_kuuj_20120102_v01.cdf
#
#                                      dir  \
# 0  D:\data\magnetometer\THEMIS\kuuj\2012
# 1  D:\data\magnetometer\THEMIS\kuuj\2012
#
#                                                 hdir
# 0  http://themis.ssl.berkeley.edu/data/themis/thg...
# 1  http://themis.ssl.berkeley.edu/data/themis/thg...

# %%
#test download
themis.download('KUUJ','2012-01-21')
# Out:
# File thg_l2_mag_kuuj_20120121_v01.cdf exists use force=True to download

# %%
#test load
df=themis.load('SNKQ','2010-01-01',ndays=5,dl=True)
# Out:
# Downloading Data:
# File thg_l2_mag_snkq_20100101_v01.cdf exists use force=True to download
# File thg_l2_mag_snkq_20100102_v01.cdf exists use force=True to download
# File thg_l2_mag_snkq_20100103_v01.cdf exists use force=True to download
# File thg_l2_mag_snkq_20100104_v01.cdf exists use force=True to download
# File thg_l2_mag_snkq_20100105_v01.cdf exists use force=True to download
# Loading: D:\data\magnetometer\THEMIS\snkq\2010\thg_l2_mag_snkq_20100101_v01.cdf
# Loading: D:\data\magnetometer\THEMIS\snkq\2010\thg_l2_mag_snkq_20100102_v01.cdf
# Loading: D:\data\magnetometer\THEMIS\snkq\2010\thg_l2_mag_snkq_20100103_v01.cdf
# Loading: D:\data\magnetometer\THEMIS\snkq\2010\thg_l2_mag_snkq_20100104_v01.cdf
# Loading: D:\data\magnetometer\THEMIS\snkq\2010\thg_l2_mag_snkq_20100105_v01.cdf

# %%
df.head()   
df.tail()
# Out:
#                          SNKQ Magnetic North - H  SNKQ Magnetic East - E   \
# t
# 2010-01-01 00:00:00.000             11084.836914                57.800999
# 2010-01-01 00:00:00.500             11084.695312                57.623001
# 2010-01-01 00:00:01.000             11084.851562                57.823002
# 2010-01-01 00:00:01.500             11084.669922                57.708000
# 2010-01-01 00:00:02.000             11084.849609                57.861000
#
#                          SNKQ Vertical Down - Z
# t
# 2010-01-01 00:00:00.000             57196.140625
# 2010-01-01 00:00:00.500             57195.980469
# 2010-01-01 00:00:01.000             57196.140625
# 2010-01-01 00:00:01.500             57195.953125
# 2010-01-01 00:00:02.000             57196.203125
#                          SNKQ Magnetic North - H  SNKQ Magnetic East - E   \
# t
# 2010-01-05 23:59:57.500             11088.264648                60.641998
# 2010-01-05 23:59:58.000             11088.380859                60.884998
# 2010-01-05 23:59:58.500             11088.198242                60.683998
# 2010-01-05 23:59:59.000             11088.349609                60.814999
# 2010-01-05 23:59:59.500             11088.196289                60.645000
#
#                          SNKQ Vertical Down - Z
# t
# 2010-01-05 23:59:57.500             57202.406250
# 2010-01-05 23:59:58.000             57202.632812
# 2010-01-05 23:59:58.500             57202.382812
# 2010-01-05 23:59:59.000             57202.593750
# 2010-01-05 23:59:59.500             57202.425781

# %%
# note you can plot with panda's, however there
#is an issue with determining the x-axis ticks
#which serverly slows plotting and is extremely
#memory intesive
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
plt.plot(df['SNKQ Magnetic North - H'])
# Out:
# <img src="data:image/png;base64,..." width="640">

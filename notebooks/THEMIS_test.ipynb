# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %matplotlib notebook

# %%
import gmag.arrays.themis as themis
import gmag.arrays.carisma as carisma
import pandas as pd
import matplotlib.pyplot as plt

import cdflib

# %%
fl = themis.list_files('KUUJ','2012-01-01',ndays=2)
fl.head()
# Out:
#         date                             fname  \
# 0 2012-01-01  thg_l2_mag_kuuj_20120101_v01.cdf
# 1 2012-01-02  thg_l2_mag_kuuj_20120102_v01.cdf
#
#                                      dir  \
# 0  D:\data\magnetometer\THEMIS\kuuj\2012
# 1  D:\data\magnetometer\THEMIS\kuuj\2012
#
#                                                 hdir
# 0  http://themis.ssl.berkeley.edu/data/themis/thg...
# 1  http://themis.ssl.berkeley.edu/data/themis/thg...

# %%
#test download
themis.download('KUUJ','2012-01-21')
# Out:
# File thg_l2_mag_kuuj_20120121_v01.cdf exists use force=True to download

# %%
#test load
df=themis.load('fsim','2012-01-22',ndays=5)
# Out:
# ...
# File thg_l2_mag_fsim_20120122_v01.cdf exists use force=True to download
# File thg_l2_mag_fsim_20120123_v01.cdf exists use force=True to download
# File thg_l2_mag_fsim_20120124_v01.cdf exists use force=True to download
# File thg_l2_mag_fsim_20120125_v01.cdf exists use force=True to download
# File thg_l2_mag_fsim_20120126_v01.cdf exists use force=True to download
# Loading: D:\data\magnetometer\THEMIS\fsim\2012\thg_l2_mag_fsim_20120122_v01.cdf
# Loading: D:\data\magnetometer\THEMIS\fsim\2012\thg_l2_mag_fsim_20120123_v01.cdf
# Loading: D:\data\magnetometer\THEMIS\fsim\2012\thg_l2_mag_fsim_20120124_v01.cdf
# Loading: D:\data\magnetometer\THEMIS\fsim\2012\thg_l2_mag_fsim_20120125_v01.cdf
# Loading: D:\data\magnetometer\THEMIS\fsim\2012\thg_l2_mag_fsim_20120126_v01.cdf

# %%
df.head()   
df.tail()
# Out:
#                          FSIM Magnetic North - H  FSIM Magnetic East - E   \
# t
# 2012-01-22 00:00:00.000             10951.251953              -196.404999
# 2012-01-22 00:00:00.500             10951.321289              -196.434998
# 2012-01-22 00:00:01.000             10951.237305              -196.425995
# 2012-01-22 00:00:01.500             10951.373047              -196.470001
# 2012-01-22 00:00:02.000             10951.279297              -196.483994
#
#                          FSIM Vertical Down - Z
# t
# 2012-01-22 00:00:00.000             58004.882812
# 2012-01-22 00:00:00.500             58004.886719
# 2012-01-22 00:00:01.000             58004.882812
# 2012-01-22 00:00:01.500             58004.886719
# 2012-01-22 00:00:02.000             58004.886719
#                          FSIM Magnetic North - H  FSIM Magnetic East - E   \
# t
# 2012-01-26 23:59:57.500             10963.593750              -213.697006
# ...

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
plt.plot(df['FSIM Magnetic North - H'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
b = carisma.load('fsim','2012-01-22')
b.head()
b.shape
# Out:
# Loading: D:\data\magnetometer\CARISMA\2012\01\22\20120122FSIM.F01.gz
#                         FSIM_X    FSIM_Y     FSIM_Z FSIM_flag        FSIM_H  \
# t
# 2012-01-22 00:00:00  10135.862  4151.331  58004.884         .  10949.097317
# 2012-01-22 00:00:01  10135.891  4151.312  58004.884         .  10949.117712
# 2012-01-22 00:00:02  10135.906  4151.259  58004.891         .  10949.112977
# 2012-01-22 00:00:03  10135.916  4151.259  58004.903         .  10949.122330
# 2012-01-22 00:00:04  10135.919  4151.291  58004.919         .  10949.136464
#
#                          FSIM_D  FSIM_declination  FSIM_cgmlat  FSIM_cgmlon  \
# t
# 2012-01-22 00:00:00  294.135177          20.73365     67.20655      295.483
# 2012-01-22 00:00:01  294.107141          20.73365     67.20655      295.483
# 2012-01-22 00:00:02  294.052263          20.73365     67.20655      295.483
# 2012-01-22 00:00:03  294.048723          20.73365     67.20655      295.483
# ...

# %%
b.plot(y=5)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
b=b.reset_index()
c = b['t'].copy()
c[0:10]

# %%
pd.to_datetime(1490195805433502912, unit='ns')
